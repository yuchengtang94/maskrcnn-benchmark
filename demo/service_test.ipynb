# %%
import argparse
import requests
from os import listdir
from os.path import join
from PIL import Image
import time

API_URL = 'http://0.0.0.0:8000/predict'
request_time = []
def predict_result(image_path):
    # Initialize image path
    start = time.time()
    image = open(image_path, 'rb').read()
    payload = {'image': image}
    
    # Submit the request.
    r = requests.post(API_URL, files=payload).json()
    request_time.append(time.time() - start)
    return r

# %%
img_path = '/workspace/coco_style_all_data/images/val/1492430406371.png'

# %%
result = predict_result(img_path)

# %%
result
# Out:
# {'bbox': [[33.32320022583008,
#    167.04676818847656,
#    128.67315673828125,
#    198.078857421875],
#   [40.25492858886719,
#    129.6131134033203,
#    180.36732482910156,
#    158.47601318359375],
#   [165.24395751953125,
#    172.2248077392578,
#    276.6977233886719,
#    203.16543579101562],
#   [520.6695556640625, 61.49187469482422, 617.7515258789062, 95.22782135009766],
#   [225.0637664794922,
#    137.83941650390625,
#    374.59124755859375,
#    166.1580352783203],
#   [178.54730224609375,
#    57.93799591064453,
#    243.84561157226562,
#    87.35990142822266],
#   [204.87619018554688,
#    97.49065399169922,
#    281.77691650390625,
#    125.62093353271484],
#   [397.9601745605469,
#    103.33644104003906,
#    502.14654541015625,
#    129.8934326171875],
#   [303.7264099121094, 61.185394287109375, 391.2669677734375, 93.39208984375],
#   [304.5455322265625,
#    177.88548278808594,
#    417.8072814941406,
#    206.5445098876953],
#   [509.0325927734375, 142.40968322753906, 575.46484375, 171.18460083007812],
#   [354.58062744140625,
#    102.48688507080078,
#    393.52447509765625,
#    128.6972198486328],
#   [510.7202453613281,
#    103.39336395263672,
#    618.5330810546875,
#    130.37586975097656],
#   [45.67993927001953,
#    90.93870544433594,
#    136.5847625732422,
#    120.82732391357422],
#   [394.2685852050781,
#    62.49346160888672,
#    457.01666259765625,
#    93.95408630371094],
#   [187.2353973388672,
#    133.45516967773438,
#    220.8779754638672,
#    159.6746063232422],
#   [138.8796844482422, 92.791259765625, 173.75108337402344, 121.31028747558594],
#   [408.06683349609375,
#    140.35641479492188,
#    449.748779296875,
#    168.3063507080078],
#   [288.5943908691406,
#    101.03163146972656,
#    323.3471374511719,
#    128.05223083496094],
#   [139.8090057373047,
#    168.1154327392578,
#    161.34124755859375,
#    197.0335693359375],
#   [331.04205322265625,
#    101.11257934570312,
#    348.09967041015625,
#    128.5099639892578],
#   [280.34619140625, 174.31454467773438, 301.7554016113281, 203.13406372070312],
#   [119.1292953491211,
#    54.24055862426758,
#    167.62164306640625,
#    83.99324035644531],
#   [250.48703002929688,
#    61.38780212402344,
#    271.8145446777344,
#    87.98778533935547],
#   [279.0896301269531, 62.2504768371582, 300.2966003417969, 90.75389099121094],
#   [484.1167907714844,
#    140.53009033203125,
#    502.83087158203125,
#    168.5486297607422],
#   [380.67193603515625, 138.95494079589844, 398.9873046875, 167.5667266845703],
#   [578.38916015625, 141.41795349121094, 598.2705078125, 170.70916748046875],
#   [178.7744140625, 96.50118255615234, 196.4808349609375, 122.06852722167969],
#   [491.6468200683594, 64.1746597290039, 514.9553833007812, 92.85672760009766],
#   [456.708740234375, 141.1036376953125, 474.3760681152344, 167.57838439941406],
#   [603.4786376953125, 141.0409698486328, 631.12646484375, 172.3743133544922],
#   [465.2502746582031, 64.2701416015625, 484.4559326171875, 92.17267608642578]],
#  'labels': [1,
#   1,
#   1,
#   1,
#   1,
#   1,
#   2,
#   2,
#   1,
#   1,
#   1,
#   1,
#   2,
#   2,
#   2,
#   2,
#   1,
#   1,
#   1,
#   2,
#   2,
#   2,
#   1,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   1,
#   2],
#  'success': True}
